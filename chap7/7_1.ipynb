# %% [markdown]
# <a href="https://colab.research.google.com/github/chaos44/generative_deep_learning/blob/main/chap7/7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b tensorflow_2 https://github.com/davidADSP/GDL_code.git
# Out:
# Cloning into 'GDL_code'...
# remote: Enumerating objects: 391, done.
# remote: Total 391 (delta 0), reused 0 (delta 0), pack-reused 391
# Receiving objects: 100% (391/391), 22.13 MiB | 35.19 MiB/s, done.
# Resolving deltas: 100% (237/237), done.

# %%
cd GDL_code/
# Out:
# /content/GDL_code

# %%
pip install --upgrade music21
# Out:
# ...
#      |████████████████████████████████| 19.2MB 165kB/s
# ...
#   Created wheel for music21: filename=music21-6.3.0-cp36-none-any.whl size=21888021 sha256=f4a2ededb2290ae7a2fdcceb81529c7690f0966a80aa3dc0672f295c6a69c391
#   Stored in directory: /root/.cache/pip/wheels/02/e8/2c/eed32afec2b6c6f945a17280c4e4df1cf2e8cd15ebe1025680
# Successfully built music21
# ...
#   Found existing installation: music21 5.5.0
#     Uninstalling music21-5.5.0:
#       Successfully uninstalled music21-5.5.0
# ...

# %%
from music21 import converter, chord, note

# %%
pip install --upgrade MusicXML
# Out:
# ERROR: Could not find a version that satisfies the requirement MusicXML (from versions: none)
# ERROR: No matching distribution found for MusicXML

# %% [markdown]
# ## **Getting the data**
# You can find midi files for each of the 36 movements in the J.S. Bach Cello Suites here:
#
# http://www.jsbach.net/midi/midi_solo_cello.html
#
# Save these inside the './data/cello' folder
#
# ## **Musical notation software**
# You'll also need to download some software to view and listen to the music generated by the model.
#
# Musescore can be freely downloaded here:
#
# https://musescore.org/en

# %%
dataset_name = 'cello'
filename = 'cs1-3cou'
file = "./data/{}/{}.mid".format(dataset_name, filename)

original_score = converter.parse(file).chordify()

# %%
original_score.show()
# Out:
# ---------------------------------------------------------------------------
# SubConverterException                     Traceback (most recent call last)
# <ipython-input-10-4545969421aa> in <module>()
# ----> 1 original_score.show()
#
# /usr/local/lib/python3.6/dist-packages/music21/stream/__init__.py in show(self, *args, **kwargs)
#     256         # ...    --- see base.py calls .write(
#     257         if self.isSorted is False and self.autoSort:
# --> 258             self.sort()
#     259         return super().show(fmt=fmt, app=app, **keywords)
#     260
#
# /usr/local/lib/python3.6/dist-packages/music21/base.py in show(self, fmt, app, **keywords)
#    2578         Displays an object in a format provided by the
#    2579         fmt argument or, if not provided, the format set in the user's Environment
# -> 2580
#    2581         Valid formats include (but are not limited to)::
#    2582             musicxml
#
# ...

# %%
original_score.show('text')

# %% [markdown]
# ## **Extracting the data**

# %%
notes = []
durations = []

for element in original_score.flat:
    
    if isinstance(element, chord.Chord):
        notes.append('.'.join(n.nameWithOctave for n in element.pitches))
        durations.append(element.duration.quarterLength)

    if isinstance(element, note.Note):
        if element.isRest:
            notes.append(str(element.name))
            durations.append(element.duration.quarterLength)
        else:
            notes.append(str(element.nameWithOctave))
            durations.append(element.duration.quarterLength)

# %%
print('\nduration', 'pitch')
for n,d in zip(notes,durations):
    print(d, '\t', n)
# Out:
# duration pitch
# 0.5 	 G3
# 0.5 	 G3
# 0.5 	 D3
# 0.5 	 G2
# 0.25 	 B3
# 0.25 	 C4
# 0.25 	 D4
# 0.25 	 C4
# 0.25 	 B3
# 0.25 	 A3
# 0.5 	 B3
# 0.5 	 D3
# 0.5 	 G2
# 0.25 	 G3
# 0.25 	 A3
# 0.5 	 B3
# 0.5 	 G3
# 0.5 	 E3
# 0.5 	 C3
# 0.5 	 C2
# 0.25 	 A3
# 0.25 	 B3
# 0.25 	 C4
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 G3
# 0.5 	 F#3
# 0.5 	 D3
# 0.5 	 D2
# 0.25 	 D3
# 0.25 	 E3
# 0.25 	 F#3
# 0.25 	 G3
# 0.25 	 A3
# 0.25 	 B3
# 0.25 	 C4
# 0.25 	 B3
# 0.25 	 C4
# 0.25 	 A3
# 0.25 	 C4
# 0.25 	 B3
# 0.25 	 C4
# 0.25 	 A3
# 0.25 	 D3
# 0.25 	 C4
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 B3
# 0.25 	 G3
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 B3
# 0.25 	 G3
# 0.25 	 C3
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 G3
# 0.25 	 F#3
# 0.25 	 A3
# 0.25 	 D4
# 0.25 	 D3
# 0.5 	 G3
# 0.5 	 B2
# 0.5 	 D2
# 0.5 	 F#3
# 1.5 	 G2.G3
# 0.25 	 B3
# 0.25 	 A3
# 0.25 	 G3
# 0.25 	 F#3
# 0.25 	 E3
# 0.25 	 D3
# 0.5 	 E4
# 0.5 	 C#4
# 0.5 	 A3
# 0.25 	 B3
# 0.25 	 C#4
# 0.25 	 D4
# 0.25 	 F#3
# 0.25 	 E3
# ...
